# %%
import pandas as pd

ratings = pd.read_csv('ml-100k/u.data', sep='\t', names=['user_id', 'movie_id', 'rating', 'timestamp'])
movies = pd.read_csv('ml-100k/u.item', sep='|', encoding='latin-1', header=None,
                     names=['movie_id', 'title', 'release_date', 'video_release_date',
                            'IMDb_URL', 'unknown', 'Action', 'Adventure', 'Animation',
                            'Children\'s', 'Comedy', 'Crime', 'Documentary', 'Drama',
                            'Fantasy', 'Film-Noir', 'Horror', 'Musical', 'Mystery',
                            'Romance', 'Sci-Fi', 'Thriller', 'War', 'Western'])

data = pd.merge(ratings, movies[['movie_id', 'title']], on='movie_id')
data.head(15)
# Out:
#     user_id  movie_id  rating  timestamp  \
# 0       196       242       3  881250949
# 1       186       302       3  891717742
# 2        22       377       1  878887116
# 3       244        51       2  880606923
# 4       166       346       1  886397596
# 5       298       474       4  884182806
# 6       115       265       2  881171488
# 7       253       465       5  891628467
# 8       305       451       3  886324817
# 9         6        86       3  883603013
# 10       62       257       2  879372434
# 11      286      1014       5  879781125
# 12      200       222       5  876042340
# 13      210        40       3  891035994
# 14      224        29       3  888104457
#
#                                                 title
# 0                                        Kolya (1996)
# 1                            L.A. Confidential (1997)
# 2                                 Heavyweights (1994)
# 3                          Legends of the Fall (1994)
# ...

# %%
print(data['rating'].min())
data['rating'].max()
# Out:
# 1
# 5

# %%
movie_stats = data.groupby('title')['rating'].agg(['mean', 'count'])
popular = movie_stats[movie_stats['count'] >= 50]
top_movies = popular.sort_values(by='mean', ascending=False)
top_movies.head(10)
# Out:
#                                                         mean  count
# title
# Close Shave, A (1995)                               4.491071    112
# Schindler's List (1993)                             4.466443    298
# Wrong Trousers, The (1993)                          4.466102    118
# Casablanca (1942)                                   4.456790    243
# Wallace & Gromit: The Best of Aardman Animation...  4.447761     67
# Shawshank Redemption, The (1994)                    4.445230    283
# Rear Window (1954)                                  4.387560    209
# Usual Suspects, The (1995)                          4.385768    267
# Star Wars (1977)                                    4.358491    583
# 12 Angry Men (1957)                                 4.344000    125

# %%
user_movie_matrix = data.pivot_table(index='user_id', columns='title', values='rating')

# %%
user_movie_matrix
# Out:
# title    'Til There Was You (1997)  1-900 (1994)  101 Dalmatians (1996)  \
# user_id
# 1                              NaN           NaN                    2.0
# 2                              NaN           NaN                    NaN
# 3                              NaN           NaN                    NaN
# 4                              NaN           NaN                    NaN
# 5                              NaN           NaN                    2.0
# ...                            ...           ...                    ...
# 939                            NaN           NaN                    NaN
# 940                            NaN           NaN                    NaN
# 941                            NaN           NaN                    NaN
# 942                            NaN           NaN                    NaN
# 943                            NaN           NaN                    NaN
#
# title    12 Angry Men (1957)  187 (1997)  2 Days in the Valley (1996)  \
# user_id
# ...

# %%
target_movie = 'Lost Highway (1997)'
target_ratings = user_movie_matrix[target_movie]
similar_movies = user_movie_matrix.corrwith(target_ratings)

corr_df = pd.DataFrame(similar_movies, columns=['correlation'])
corr_df.dropna(inplace=True)
corr_df = corr_df.join(movie_stats['count'])
# Out:
# C:\Users\ssson\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\numpy\lib\function_base.py:2889: RuntimeWarning: Degrees of freedom <= 0 for slice
#   c = cov(x, y, rowvar, dtype=dtype)
# C:\Users\ssson\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\numpy\lib\function_base.py:2748: RuntimeWarning: divide by zero encountered in divide
#   c *= np.true_divide(1, fact)
# C:\Users\ssson\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\numpy\lib\function_base.py:2748: RuntimeWarning: invalid value encountered in multiply
#   c *= np.true_divide(1, fact)
# ...

# %%
recommendations = corr_df[corr_df['count'] >= 50].sort_values('correlation', ascending=False)
recommendations.head(10)
# Out:
#                                 correlation  count
# title
# Lost Highway (1997)                1.000000    125
# Wyatt Earp (1994)                  1.000000     50
# Thin Man, The (1934)               0.944911     60
# Antonia's Line (1995)              0.895761     69
# Muppet Treasure Island (1996)      0.894792     84
# Circle of Friends (1995)           0.798762     76
# Escape from L.A. (1996)            0.751360     91
# Victor/Victoria (1982)             0.750000     77
# Man Without a Face, The (1993)     0.707107     68
# Philadelphia Story, The (1940)     0.707107    104
