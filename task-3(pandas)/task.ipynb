# %%
import pandas as pd
import numpy as np

file_name = 'Energy Indicators.xls'

def read_energy_indicators(file_name):
	energy = pd.read_excel(file_name, header=None, skiprows=17, usecols='C:F', nrows=228)
	energy.columns = ['Country', 'Energy Supply', 'Energy Supply per Capita', '% Renewable']

	energy.replace('...', np.NaN, inplace=True)
	energy['Energy Supply'] *= 1000000
	energy.loc[0, 'Energy Supply'] = 'Gigajoules'

	return energy

energy = read_energy_indicators(file_name)
energy
# Out:
#                        Country Energy Supply Energy Supply per Capita  \
# 0                          NaN    Gigajoules               Gigajoules
# 1                  Afghanistan     321000000                       10
# 2                      Albania     102000000                       35
# 3                      Algeria    1959000000                       51
# 4               American Samoa           NaN                      NaN
# ..                         ...           ...                      ...
# 223                   Viet Nam    2554000000                       28
# 224  Wallis and Futuna Islands             0                       26
# 225                      Yemen     344000000                       13
# 226                     Zambia     400000000                       26
# 227                   Zimbabwe     480000000                       32
#
#     % Renewable
# 0             %
# 1      78.66928
# 2           100
# 3       0.55101
# 4      0.641026
# ..          ...
# ...

# %%
def change_countries():
	original_energy = energy.copy()
	energy['Country'] = energy['Country'].str.replace(r'\s?\(\S.*\)|\d+', '', regex=True)

	energy['Country'] = energy['Country'].replace({
		'Republic of Korea': 'South Korea',
		'United States of America': 'United States',
		'United Kingdom of Great Britain and Northern Ireland': 'United Kingdom',
		'China, Hong Kong Special Administrative Region': 'Hong Kong'
	})

	changed_values = original_energy['Country'].compare(energy['Country'])
	return changed_values

print(change_countries())
# Out:
#                                                   self  \
# 12                                          Australia1
# 25                    Bolivia (Plurinational State of)
# 43                                              China2
# 44     China, Hong Kong Special Administrative Region3
# 45         China, Macao Special Administrative Region4
# 59                                            Denmark5
# 71                         Falkland Islands (Malvinas)
# 74                                             France6
# 84                                          Greenland7
# 98                                          Indonesia8
# 99                          Iran (Islamic Republic of)
# 104                                             Italy9
# 106                                            Japan10
# 112                                           Kuwait11
# 134                   Micronesia (Federated States of)
# 144                                      Netherlands12
# ...

# %%
file2_name = 'world_bank.csv'
GPD = pd.read_csv(file2_name, skiprows=4)
GPD
# Out:
#                     Country Name Country Code     Indicator Name  \
# 0                          Aruba          ABW  GDP (current US$)
# 1    Africa Eastern and Southern          AFE  GDP (current US$)
# 2                    Afghanistan          AFG  GDP (current US$)
# 3     Africa Western and Central          AFW  GDP (current US$)
# 4                         Angola          AGO  GDP (current US$)
# ..                           ...          ...                ...
# 261                       Kosovo          XKX  GDP (current US$)
# 262                  Yemen, Rep.          YEM  GDP (current US$)
# 263                 South Africa          ZAF  GDP (current US$)
# 264                       Zambia          ZMB  GDP (current US$)
# 265                     Zimbabwe          ZWE  GDP (current US$)
#
#      Indicator Code          1960          1961          1962          1963  \
# 0    NY.GDP.MKTP.CD           NaN           NaN           NaN           NaN
# ...

# %%
def change_countries_GPD():
	original_GPD = GPD.copy()
	GPD['Country Name'] = GPD['Country Name'].replace({
		'Korea, Rep.': 'South Korea',
		'Iran, Islamic Rep.': 'Iran',
		'Hong Kong SAR, China': 'Hong Kong'
	})
	changed_values = original_GPD['Country Name'].compare(GPD['Country Name'])
	return changed_values
print(change_countries_GPD())
# Out:
#                      self        other
# 96   Hong Kong SAR, China    Hong Kong
# 112    Iran, Islamic Rep.         Iran
# 126           Korea, Rep.  South Korea

# %%
file3_name = 'Sciamgo Journal and Country Rank.xlsx'
ScimEn = pd.read_excel(file3_name)
ScimEn
# Out:
#      Rank           Country            Region  Documents  Citable documents  \
# 0       1             China    Asiatic Region     402188             400158
# 1       2     United States  Northern America     208042             203356
# 2       3             India    Asiatic Region      81853              79757
# 3       4             Japan    Asiatic Region      58342              57735
# 4       5    United Kingdom    Western Europe      56288              54713
# ..    ...               ...               ...        ...                ...
# 208   209  Marshall Islands    Pacific Region          1                  1
# 209   210           Grenada     Latin America          1                  1
# 210   211        Montserrat     Latin America          1                  1
# 211   212  Christmas Island    Pacific Region          1                  1
# 212   213           Curaçao     Latin America          1                  1
#
# ...

# %%
GPD.rename(columns={'Country Name': 'Country'}, inplace=True)
def answer_one():
	top15 = ScimEn[ScimEn['Rank'] <= 15]
	years = GPD[['Country'] + [str(year) for year in range(2006, 2016)]]

	merged_data = pd.merge(top15, energy, on='Country', how='inner')
	merged_data = pd.merge(merged_data, years, on='Country', how='inner')

	merged_data.set_index('Country', inplace=True)


	return merged_data.head(15)
answer_one()
# Out:
#                     Rank            Region  Documents  Citable documents  \
# Country
# China                  1    Asiatic Region     402188             400158
# United States          2  Northern America     208042             203356
# India                  3    Asiatic Region      81853              79757
# Japan                  4    Asiatic Region      58342              57735
# United Kingdom         5    Western Europe      56288              54713
# Germany                6    Western Europe      50906              49773
# Russian Federation     7    Eastern Europe      46186              45868
# Canada                 8  Northern America      41209              40390
# Italy                  9    Western Europe      38700              36909
# South Korea           10    Asiatic Region      38362              38046
# Iran                  11       Middle East      32080              31725
# France                12    Western Europe      30810              30139
# ...

# %%
merged = answer_one()
merged.columns
# Out:
# Index(['Rank', 'Region', 'Documents', 'Citable documents', 'Citations',
#        'Self-citations', 'Citations per document', 'H index', 'Energy Supply',
#        'Energy Supply per Capita', '% Renewable', '2006', '2007', '2008',
#        '2009', '2010', '2011', '2012', '2013', '2014', '2015'],
#       dtype='object')

# %%
def answer_two():
	columns = [str(year) for year in range(2006, 2016)]
	avgGPD = merged[columns].mean(axis=1, skipna=True)
	return avgGPD.sort_values(ascending=False)
answer_two()
# Out:
# Country
# United States         1.572243e+13
# China                 6.927707e+12
# Japan                 5.239642e+12
# Germany               3.590729e+12
# United Kingdom        2.777505e+12
# France                2.692000e+12
# Italy                 2.152983e+12
# Brazil                1.988889e+12
# Russian Federation    1.666746e+12
# Canada                1.616359e+12
# India                 1.602352e+12
# Spain                 1.406644e+12
# South Korea           1.221328e+12
# Australia             1.207997e+12
# Iran                  4.567516e+11
# dtype: float64

# %%
avgGPD = answer_two()
def answer_three():
	return merged.loc[avgGPD.index[5], '2015']  - merged.loc[avgGPD.index[5], '2006']
answer_three()
# Out:
# 124621907951.68018

# %%
def answer_four():
	merged['Ratio'] = merged['Self-citations'] / merged['Citations']
	max_ratio = merged['Ratio'].max()
	country_max_ratio = merged['Ratio'].idxmax()
	return (country_max_ratio, max_ratio)
answer_four()
# Out:
# ('China', 0.6916510807463594)

# %%
def answer_five():
	merged['Estimated Population'] = merged['Energy Supply'] / merged['Energy Supply per Capita']
	estimated_pop = merged['Estimated Population'].sort_values(ascending=False)
	return str(estimated_pop.index[2])
answer_five()
# Out:
# 'United States'

# %%
def answer_six():
	merged['Citable Doc per Person'] = merged['Citable documents'] / merged['Estimated Population']
	correlation = merged['Citable Doc per Person'].corr(merged['Energy Supply per Capita'])
	return correlation
answer_six()
# Out:
# 0.7019601723071188

# %%
ContinentDict  = {'China':'Asia', 
	'United States':'North America', 
	'Japan':'Asia', 
	'United Kingdom':'Europe', 
	'Russian Federation':'Europe', 
	'Canada':'North America', 
	'Germany':'Europe', 
	'India':'Asia',
	'France':'Europe', 
	'South Korea':'Asia', 
	'Italy':'Europe', 
	'Spain':'Europe', 
	'Iran':'Asia',
	'Australia':'Australia', 
	'Brazil':'South America'}
def answer_seven():
  merged['Continent'] = merged.index.map(ContinentDict)
  df = merged.groupby('Continent')['Estimated Population'].agg(['size', 'sum', 'mean', 'std'])

  return df
answer_seven()
# Out:
#                size               sum              mean           std
# Continent
# Asia              5   2898666386.6106   579733277.32212  6.790979e+08
# Australia         1   23316017.316017   23316017.316017           NaN
# Europe            6  457929667.216372   76321611.202729  3.464767e+07
# North America     2   352855249.48025  176427624.740125  1.996696e+08
# South America     1  205915254.237288  205915254.237288           NaN
